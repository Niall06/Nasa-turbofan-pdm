# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# The dataset does not include collumn headings so these must be implemented 

index_names = ['unit_num','cycle_num']
setting_names = ['Altitude','Mach_Number','Throttle_position']
# Now for the 21 sensors:
sensor_names = []
for i in range(1,22):
    a = 's_'+ str(i)
    sensor_names.append(a)
# Overall collumn names 
column_names = index_names + setting_names + sensor_names
data = pd.read_csv('../data/train_FD001.txt', sep='\s+', header=None, names=column_names)

# The '..' before the cell tells python to move out the current file to the parent cell and then move into data
# The names functions allows us to give names to all of the collumns

# %% [markdown]
# As the plane is tested at sea level, all the values of alititide should be the same (approximately) - this is shown below
